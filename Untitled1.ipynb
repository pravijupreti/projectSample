# %%
print("ggg")
# Out:
# ggg

# %%
print("ggg")
# Out:
# ggg

# %%
print("ggg realtime change detection jhvkhg hff")
# Out:
# ggg realtime change detection jhvkhg hff

# %%
print("ggg realtime change detection jhvkhg hff")
# Out:
# ggg realtime change detection jhvkhg hff

# %%
print("ggg realtime change detection jhvkhg hff")
# Out:
# ggg realtime change detection jhvkhg hff

# %%
import tensorflow as tf

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print("GPU is available:", gpus)
else:
    print("No GPU detected")
# Out:
# 2026-03-11 11:50:38.786546: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-03-11 11:50:38.786700: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-03-11 11:50:38.845987: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-03-11 11:50:38.969946: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
print("THis is realtime")
# Out:
# THis is realtime

# %%
print("THis is realtime")
# Out:
# THis is realtime

# %%
print("THis is realtime")
# Out:
# THis is realtime
